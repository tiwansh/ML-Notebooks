# %%
# !pip install bs4
# Out:
# ...
#   Using cached beautifulsoup4-4.9.1-py3-none-any.whl (115 kB)
# ...
#   Using cached soupsieve-2.0.1-py3-none-any.whl (32 kB)
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=d2341902e359a088f7ded1b18414c9851c2e54a86bd5c017fa3c6c8fd15c114e
#   Stored in directory: /home/local/SIRIONLABS/anshuman.tiwari1/.cache/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# Successfully built bs4
# ...
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/local/SIRIONLABS/anshuman.tiwari1/virtual_environments/ml_venv/bin/python3 -m pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(open("/home/local/SIRIONLABS/anshuman.tiwari1/Downloads/htmls/5.html", "rb"))

# %%
print(soup.body.text)
# Out:
# INVOICE
# energy services
# INVOICE #
# INVOICE DATE
# INV00017934
# Mar 02, 2017
# 300, 505 - 3rd Street SW Calgary, AB T2P 3E6 Phone: (403) 457-1772
# TERMS:             Net 30 Days
# TO:
# Shell Canada Energy
# PO Box 2247, Station 100
# Calgary, AB, T2P 2M6
#
#
# FOR:
#
#
#
# LSD:
# 12-13-65-22 w5
#
# Province:
# Alberta
#
# Job #:
# J00029133
#
# Ticket #:
# FRC00004310
#
# Ticket Date:
# Mar 02, 2017
#
# AFE #:
# 30260920-4201
#
# PO#:
# 4900025622
#
#
#
#
# ITEM/DESCRIPTION                                            QUANTITY    RATE         AMOUNT
#
# Dust Control (Vacuum System) Fracturing Spread Rig in/out Fracturing Spread Standby
# Pressure Relief Valve (N2 PRV Option) Proppant Storage Unit
# Subsistence
# 1
# 1
# 3
# 1
# 1
# 47
# 2,250.00
# $      2,250.00
#
# 65.1
# inn
# 1.00
# S    65
# inn
# 1.00
#
# 2,375.00
# $      7,718.75
#
# 1.1
# inn
# 1.00
# S        1.1
# inn
# LOO
#
# 10,152.00
# 175.00
# $     10,152.00
# $      8,225.00
#
# SUB-TOTAL    $    94,345.75
# ...
